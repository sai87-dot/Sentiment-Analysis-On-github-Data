# %%
import pandas as pd, numpy as np,matplotlib.pyplot as plt, seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\bsai1\\Downloads\\reviews_data_dump (1)\\reviews_tawa\\data.csv")

# %%
data
# Out:
#           Reviewer_Name  Reviewer_Rating           Review_Title  \
# 0          Sumit  Kumar              5.0              Wonderful
# 1       BHARAT GALAGALI              5.0  Mind-blowing purchase
# 2       Paramjeet Singh              5.0                Awesome
# 3       Virendra  Kumar              5.0          Great product
# 4         jyoti solanki              5.0    Best in the market!
# ...                 ...              ...                    ...
# 2526  Sandeep Mohapatra              3.0                   Fair
# 2527        Vakul  Rana              4.0   Good quality product
# 2528  Somraj  Dhungana               4.0            Really Nice
# 2529       Veeranna N C              3.0                   Good
# 2530  Flipkart Customer              3.0              Just okay
#
#                                             Review_Text  \
# 0     I think In this price category it's best dosa ...
# 1                      perfect tawa for Dosa..READ MORE
# ...

# %%
data.columns
# Out:
# Index(['Reviewer_Name', 'Reviewer_Rating', 'Review_Title', 'Review_Text',
#        'Place_of_Review', 'Date_of_Review', 'Up_Votes', 'Down_Votes'],
#       dtype='object')

# %%
data.loc[0]
# Out:
# Reviewer_Name                                           Sumit  Kumar
# Reviewer_Rating                                                  5.0
# Review_Title                                               Wonderful
# Review_Text        I think In this price category it's best dosa ...
# Place_of_Review                          Certified Buyer, Lakhisarai
# Date_of_Review                                          Sumit  Kumar
# Up_Votes                                                         211
# Down_Votes                                                        39
# Name: 0, dtype: object

# %%
data.values[0]
# Out:
# array(['Sumit  Kumar', 5.0, 'Wonderful',
#        "I think In this price category it's best dosa tawa. I tried it and it turned out to be great. Thanks Flipkart!READ MORE",
#        'Certified Buyer, Lakhisarai', 'Sumit  Kumar', 211, 39],
#       dtype=object)

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer



# 1. Text Preprocessing for `Review_Title` and `Review_Text`
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove special characters and digits
    text = re.sub(r'[^a-z\s]', '', text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    text = " ".join([word for word in text.split() if word not in stop_words])
    # Lemmatize text
    lemmatizer = WordNetLemmatizer()
    text = " ".join([lemmatizer.lemmatize(word) for word in text.split()])
    return text

# Combine Review_Title and Review_Text for unified preprocessing
data['review_combined'] = data['Review_Title'] + " " + data['Review_Text']
data['review_combined_cleaned'] = data['review_combined'].apply(preprocess_text)

# 2. Process Numerical Columns
# Create a net engagement feature
data['net_engagement'] = data['Up_Votes'] - data['Down_Votes']

# 3. Sentiment Labeling Based on Reviewer_Rating
def label_sentiment(rating):
    if rating >= 4:
        return 'positive'
    elif rating <= 2:
        return 'negative'
    else:
        return 'neutral'

data['sentiment'] = data['Reviewer_Rating'].apply(label_sentiment)

# 4. Correct `Date_of_Review` (Assume placeholder is wrong; replace with a valid date for analysis)
data['Date_of_Review'] = pd.to_datetime('2024-11-30')  # Replace with actual date when available

# Display the processed DataFrame
print(data)
# Out:
#           Reviewer_Name  Reviewer_Rating           Review_Title  \
# 0          Sumit  Kumar              5.0              Wonderful
# 1       BHARAT GALAGALI              5.0  Mind-blowing purchase
# 2       Paramjeet Singh              5.0                Awesome
# 3       Virendra  Kumar              5.0          Great product
# 4         jyoti solanki              5.0    Best in the market!
# ...                 ...              ...                    ...
# 2526  Sandeep Mohapatra              3.0                   Fair
# 2527        Vakul  Rana              4.0   Good quality product
# 2528  Somraj  Dhungana               4.0            Really Nice
# 2529       Veeranna N C              3.0                   Good
# 2530  Flipkart Customer              3.0              Just okay
#
#                                             Review_Text  \
# 0     I think In this price category it's best dosa ...
# 1                      perfect tawa for Dosa..READ MORE
# ...
